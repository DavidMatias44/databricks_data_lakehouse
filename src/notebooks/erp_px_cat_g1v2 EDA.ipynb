# %% [markdown]
# # `erp_px_cat_g1v2` Exploratory Data Analysis

# %% [markdown]
# ## Init

# %%
from pyspark.sql.functions import col

# %% [markdown]
# ## Reading from Bronze layer

# %%
df = spark.table("lakehouse_project.bronze.erp_px_cat_g1v2")

# %% [markdown]
# ## Exploring the data

# %%
df.show(20)

# %% [markdown]
# ## Issues found

# %% [markdown]
# 1. Column names do not follow any naming convention (e.g. `ID` instead of `product_id`, `CAT` instead of `category_id`).
